# %% [markdown]
# ![Projet AuFilDuBoamp bandeau](https://raw.githubusercontent.com/Semaine52/AuFilDuBoamp_Atelier/main/images/bandeau_aufilduboamp_notebooks.svg "Projet AuFilDuBoamp")

# %%
import os
import pandas as pd

# %%
from urllib.request import urlretrieve

URL = "https://raw.githubusercontent.com/Semaine52/AuFilDuBoamp_Atelier/main/scripts/afdb_lab_prereglages.py"
URL2 = "https://raw.githubusercontent.com/Semaine52/AuFilDuBoamp_Atelier/main/scripts/afdb_outils_csv.py"
urlretrieve(URL, "temp/prereglages_s52_lab.py")
urlretrieve(URL2, "temp/afdb_outils_csv.py")
# %run prereglages_s52_lab
# %run afdb_outils_csv.py
# Out:
# ('temp/prereglages_s52_lab.py', <http.client.HTTPMessage at 0x1719489bd60>)
# ('temp/afdb_outils_csv.py', <http.client.HTTPMessage at 0x171949c10a0>)

# %%
x = BOAMP_2021_GITHUB_CSV[1]

# %%
pd.read_csv(x)
# Out:
#      BOAMP_AVIS_NUM  D_02_01_Typeorganisme_Institutioneuropeenne  \
# 0         11-116542                                        False
# 1         19-174419                                        False
# 2         19-188040                                        False
# 3          19-99055                                        False
# 4         20-106925                                        False
# ...             ...                                          ...
# 4345        21-9989                                        False
# 4346        21-9990                                        False
# 4347        21-9995                                        False
# 4348        21-9996                                        False
# 4349        21-9997                                        False
#
#       D_02_02_Typeorganisme_Etat  D_02_03_Typeorganisme_Region  \
# 0                          False                         False
# ...
